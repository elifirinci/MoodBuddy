# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, BatchNormalization, Activation, 
                                     MaxPooling2D, Dropout, Flatten, Dense)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns


main_dir = '/kaggle/input/emotions'
train_dir = os.path.join(main_dir, "train")
test_dir = os.path.join(main_dir, "test")

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,       
    width_shift_range=0.1,   
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)


test_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(64, 64),
    batch_size=32,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=True
)


test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(64, 64),
    batch_size=32,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=False
)

# Model architecture
model = Sequential([
    # First Conv Layer
    Conv2D(64, (3, 3), padding='same', input_shape=(64, 64, 1)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),

    # Second Conv Layer
    Conv2D(128, (3, 3), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),

    # Third Conv Layer
    Conv2D(256, (3, 3), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),

    # Fully connected layers
    Flatten(),
    Dense(512),               
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    Dense(len(train_generator.class_indices), activation='softmax') 
])

model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=['accuracy']
)


model.summary()


callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
]


history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=50, 
    callbacks=callbacks
)


Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

y_true = test_generator.classes


plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

class_labels = list(test_generator.class_indices.keys())


cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()


print("Classification Report:")
class_labels = list(test_generator.class_indices.keys())
print(classification_report(y_true, y_pred, target_names=class_labels))

plt.figure(figsize=(10, 6))
for i, label in enumerate(class_labels):
    true_indices = np.where(y_true == i)[0]
    plt.scatter(true_indices, Y_pred[true_indices, i], label=f'{label}', alpha=0.6)

plt.title('Scatter Plot of True Labels vs Predicted Probabilities')
plt.xlabel('Sample Index')
plt.ylabel('Predicted Probability')
plt.legend()
plt.grid()
plt.show()

model.save('/kaggle/working/emotion_classification_model.h5')
# Out:
# Found 23308 images belonging to 5 classes.
# Found 5834 images belonging to 5 classes.
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 64, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     8,389,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,765,189 (33.44 MB)
#  Trainable params: 8,763,269 (33.43 MB)
#  Non-trainable params: 1,920 (7.50 KB)
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 729/729 - 461s - 632ms/step - accuracy: 0.3670 - loss: 1.5889 - val_accuracy: 0.4784 - val_loss: 1.2602 - learning_rate: 0.0010
# Epoch 2/50
# 729/729 - 449s - 616ms/step - accuracy: 0.4795 - loss: 1.2575 - val_accuracy: 0.5310 - val_loss: 1.1509 - learning_rate: 0.0010
# Epoch 3/50
# 729/729 - 449s - 616ms/step - accuracy: 0.5269 - loss: 1.1620 - val_accuracy: 0.4379 - val_loss: 1.3900 - learning_rate: 0.0010
# Epoch 4/50
# 729/729 - 450s - 617ms/step - accuracy: 0.5462 - loss: 1.1103 - val_accuracy: 0.5610 - val_loss: 1.0923 - learning_rate: 0.0010
# Epoch 5/50
# 729/729 - 449s - 616ms/step - accuracy: 0.5680 - loss: 1.0653 - val_accuracy: 0.4074 - val_loss: 1.4911 - learning_rate: 0.0010
# Epoch 6/50
# 729/729 - 482s - 661ms/step - accuracy: 0.5797 - loss: 1.0412 - val_accuracy: 0.6174 - val_loss: 0.9434 - learning_rate: 0.0010
# Epoch 7/50
# 729/729 - 449s - 617ms/step - accuracy: 0.5888 - loss: 1.0140 - val_accuracy: 0.6135 - val_loss: 0.9727 - learning_rate: 0.0010
# Epoch 8/50
# 729/729 - 426s - 584ms/step - accuracy: 0.6045 - loss: 0.9901 - val_accuracy: 0.6203 - val_loss: 0.9684 - learning_rate: 0.0010
# Epoch 9/50
# 729/729 - 426s - 585ms/step - accuracy: 0.6110 - loss: 0.9711 - val_accuracy: 0.5910 - val_loss: 1.0275 - learning_rate: 0.0010
# Epoch 10/50
# 729/729 - 449s - 616ms/step - accuracy: 0.6324 - loss: 0.9150 - val_accuracy: 0.6565 - val_loss: 0.8689 - learning_rate: 5.0000e-04
# Epoch 11/50
# 729/729 - 427s - 586ms/step - accuracy: 0.6400 - loss: 0.8985 - val_accuracy: 0.6004 - val_loss: 0.9792 - learning_rate: 5.0000e-04
# Epoch 12/50
# 729/729 - 424s - 581ms/step - accuracy: 0.6423 - loss: 0.8888 - val_accuracy: 0.6611 - val_loss: 0.8546 - learning_rate: 5.0000e-04
# Epoch 13/50
# 729/729 - 423s - 581ms/step - accuracy: 0.6544 - loss: 0.8721 - val_accuracy: 0.6558 - val_loss: 0.8586 - learning_rate: 5.0000e-04
# Epoch 14/50
# 729/729 - 422s - 578ms/step - accuracy: 0.6540 - loss: 0.8570 - val_accuracy: 0.6610 - val_loss: 0.8650 - learning_rate: 5.0000e-04
# Epoch 15/50
# 729/729 - 424s - 581ms/step - accuracy: 0.6604 - loss: 0.8464 - val_accuracy: 0.6644 - val_loss: 0.8515 - learning_rate: 5.0000e-04
# Epoch 16/50
# 729/729 - 421s - 578ms/step - accuracy: 0.6670 - loss: 0.8318 - val_accuracy: 0.6102 - val_loss: 1.0031 - learning_rate: 5.0000e-04
# Epoch 17/50
# 729/729 - 445s - 611ms/step - accuracy: 0.6713 - loss: 0.8313 - val_accuracy: 0.6575 - val_loss: 0.8750 - learning_rate: 5.0000e-04
# Epoch 18/50
# 729/729 - 419s - 574ms/step - accuracy: 0.6747 - loss: 0.8167 - val_accuracy: 0.6752 - val_loss: 0.8309 - learning_rate: 5.0000e-04
# Epoch 19/50
# 729/729 - 423s - 580ms/step - accuracy: 0.6762 - loss: 0.8139 - val_accuracy: 0.6784 - val_loss: 0.8342 - learning_rate: 5.0000e-04
# Epoch 20/50
# 729/729 - 425s - 582ms/step - accuracy: 0.6816 - loss: 0.8024 - val_accuracy: 0.6702 - val_loss: 0.8593 - learning_rate: 5.0000e-04
# Epoch 21/50
# 729/729 - 425s - 583ms/step - accuracy: 0.6899 - loss: 0.7873 - val_accuracy: 0.6202 - val_loss: 0.9910 - learning_rate: 5.0000e-04
# Epoch 22/50
# 729/729 - 445s - 611ms/step - accuracy: 0.6997 - loss: 0.7647 - val_accuracy: 0.6896 - val_loss: 0.7998 - learning_rate: 2.5000e-04
# Epoch 23/50
# 729/729 - 424s - 582ms/step - accuracy: 0.7047 - loss: 0.7477 - val_accuracy: 0.6860 - val_loss: 0.8146 - learning_rate: 2.5000e-04
# Epoch 24/50
# 729/729 - 422s - 579ms/step - accuracy: 0.7035 - loss: 0.7457 - val_accuracy: 0.6853 - val_loss: 0.8180 - learning_rate: 2.5000e-04
# Epoch 25/50
# 729/729 - 430s - 590ms/step - accuracy: 0.7134 - loss: 0.7348 - val_accuracy: 0.6889 - val_loss: 0.8075 - learning_rate: 2.5000e-04
# Epoch 26/50
# 729/729 - 431s - 592ms/step - accuracy: 0.7172 - loss: 0.7206 - val_accuracy: 0.7012 - val_loss: 0.7795 - learning_rate: 1.2500e-04
# Epoch 27/50
# 729/729 - 425s - 583ms/step - accuracy: 0.7183 - loss: 0.7172 - val_accuracy: 0.7036 - val_loss: 0.7816 - learning_rate: 1.2500e-04
# Epoch 28/50
# 729/729 - 425s - 583ms/step - accuracy: 0.7163 - loss: 0.7191 - val_accuracy: 0.7059 - val_loss: 0.7701 - learning_rate: 1.2500e-04
# Epoch 29/50
# 729/729 - 424s - 582ms/step - accuracy: 0.7239 - loss: 0.7044 - val_accuracy: 0.6973 - val_loss: 0.7892 - learning_rate: 1.2500e-04
# Epoch 30/50
# 729/729 - 444s - 609ms/step - accuracy: 0.7239 - loss: 0.7023 - val_accuracy: 0.7035 - val_loss: 0.7860 - learning_rate: 1.2500e-04
# Epoch 31/50
# 729/729 - 426s - 585ms/step - accuracy: 0.7273 - loss: 0.6945 - val_accuracy: 0.7028 - val_loss: 0.7807 - learning_rate: 1.2500e-04
# Epoch 32/50
# 729/729 - 427s - 586ms/step - accuracy: 0.7322 - loss: 0.6875 - val_accuracy: 0.7047 - val_loss: 0.7836 - learning_rate: 6.2500e-05
# Epoch 33/50
# 729/729 - 439s - 602ms/step - accuracy: 0.7297 - loss: 0.6917 - val_accuracy: 0.7064 - val_loss: 0.7729 - learning_rate: 6.2500e-05
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.63      0.62      0.63       958
#      fearful       0.59      0.39      0.47      1024
#        happy       0.85      0.91      0.88      1774
#          sad       0.58      0.70      0.63      1247
#    surprised       0.79      0.77      0.78       831
#
#     accuracy                           0.71      5834
#    macro avg       0.69      0.68      0.68      5834
# weighted avg       0.70      0.71      0.70      5834
